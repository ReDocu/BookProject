# %%
# 단순 윈도우 출력하기
import pygame

import sys
import pygame

from pygame.locals import QUIT

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
pygame.display.set_caption('just window')

def main():
    # main routine
    while True:
        SURFACE.fill((255,255,255))
        
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
        
        pygame.display.update()

# main 함수
if __name__ == '__main__':
    main()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\GJ\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# FPS 기본
import pygame

import sys
import pygame

from pygame.locals import QUIT

pygame.init()
SURFACE = pygame.display.set_mode((400,300))

def main():
    
    sysfont = pygame.font.SysFont(None, 36)
    counter = 0
    
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
        
        counter += 1
        SURFACE.fill((0,0,0))
        count_image = sysfont.render('count is {}'.format(counter), True, (225,225,225))
        SURFACE.blit(count_image,(50,50))
        
        
        pygame.display.update()

# main 함수
if __name__ == '__main__':
    main()

# %%
# FPS 시간 제한 하기
import pygame

import sys
import pygame

from pygame.locals import QUIT

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    
    sysfont = pygame.font.SysFont(None, 36)
    counter = 0
    
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
        
        counter += 1
        SURFACE.fill((0,0,0))
        count_image = sysfont.render('count is {}'.format(counter), True, (225,225,225))
        SURFACE.blit(count_image,(50,50))
        
        
        pygame.display.update()
        FPSCLOCK.tick(10)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 사각형 그리기
import pygame

import sys
import pygame

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((255,255,255))

        # 빨간색 직사각형 (꽉 채워 칠한다)
        pygame.draw.rect(SURFACE, (255,0,0), (10,20,100,50))
        
        # 빨간색 : 직사각형(굵기 3)
        pygame.draw.rect(SURFACE, (255,0,0), (150,10,100,30),3)
        
        # 녹색 : 직사각형
        pygame.draw.rect(SURFACE, (0,255,0), ((100,80),(80,50)))

        # 파란색 : 직사각형, Rect 객체
        rect0 = Rect(200,60,140,80)
        # 노란색 : 직사각형, Rect 객체
        rect1 = Rect((30,160),(100,50))
        
        # 사각형 그리기
        pygame.draw.rect(SURFACE, (0,0,255), rect0)
        pygame.draw.rect(SURFACE, (255,255,0), rect1)
                
        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 원 그리기
import pygame

import sys
import pygame

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((255,255,255))

        # 빨간색 : 꽉 채워 칠한다.
        pygame.draw.circle(SURFACE, (255,0,0), (50,50), 20)
        
        # 빨간색 : 굵기 10
        pygame.draw.circle(SURFACE, (255,0,0), (150,50), 20, 10)
        
        # 녹색 : 반경 10
        pygame.draw.circle(SURFACE, (0,255,0), (50,150), 10)
        # 녹색 : 반경 20
        pygame.draw.circle(SURFACE, (0,255,0), (150,150), 20)
        # 녹색 : 반경 30
        pygame.draw.circle(SURFACE, (0,255,0), (250,150), 30)
        

        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 타원 그리기
import pygame

import sys
import pygame

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((255,255,255))

        # 빨간색
        pygame.draw.ellipse(SURFACE, (255,0,0), (50, 50, 140, 60))
        pygame.draw.ellipse(SURFACE, (255,0,0), (250,30,90,90))
        
        # 녹색
        pygame.draw.ellipse(SURFACE, (0,255,0), (50,150,110,60), 5)
        pygame.draw.ellipse(SURFACE, (0,255,0), ((250,130),(90,90)),20)
        

        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 선 그리기
import pygame

import sys
import pygame

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((255,255,255))

        # 빨간색 : 가로줄  색깔 시작, 종점
        pygame.draw.line(SURFACE, (255,0,0),(10,80),(200,80))
        
        # 빨간색 : 가로줄 (굵기 15)
        pygame.draw.line(SURFACE, (255,0,0), (10, 150), (200, 150), 15)
        
        # 녹색 : 세로줄
        pygame.draw.line(SURFACE, (0,255,0), (250, 30), (250, 200))
        
        # 녹색 : 빗금 (굵기 10)
        start_pos = (300,30)
        end_pos = (380, 200)
        pygame.draw.line(SURFACE, (0,0,255), start_pos, end_pos, 10)

        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
#선 그리기 (응용) - 사각 공간 그리기

import pygame

import sys
import pygame

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((0,0,0))

        # 하얀색 : 세로줄
        for xpos in range(0, 400, 25):
            pygame.draw.line(SURFACE, 0xFFFFFF, (xpos, 0), (xpos, 300))
        
        # 하얀색 : 가로줄
        for ypos in range(0, 300, 25):
            pygame.draw.line(SURFACE, 0xFFFFF, (0, ypos), (400, ypos))
        
        
        
        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 선 그리기 (응용) - 랜덤으로 선 그리기
import pygame

import sys
import pygame

import random

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((0,0,0))

        pointlist = []
        for _ in range(10):
            xpos = random.randint(0,400)
            ypos = random.randint(0,300)
            pointlist.append((xpos,ypos))
            
        pygame.draw.lines(SURFACE, (255,255,255), True, pointlist, 5)
        
        
        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 폴리곤 - 마름모 그리기
import pygame

import sys
import pygame

import random

from math import sin, cos, radians

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((0,0,0))

        pointlist0 = []
        pointlist1 = []
        
        for theta in range(0,360, 72):
            rad = radians(theta)
            
            pointlist0.append((cos(rad)*100 + 100, sin(rad)*100 + 150))
            pointlist1.append((cos(rad)*100 + 300, sin(rad)*100 + 150))
        
        pygame.draw.lines(SURFACE, (255,255,255), True, pointlist0)
        pygame.draw.polygon(SURFACE, (255,255,255), pointlist1)
            
            
        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 이미지 불러오기
import pygame

import sys
import pygame

import random

from math import sin, cos, radians

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    
    # 매개변수 : 파일경로
    logo = pygame.image.load('pygamelogo.jpg')
    
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((0,0,0))

        # 
        SURFACE.blit(logo, (20,50))
       
        
        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 이미지 일부만 그리기
import pygame

import sys
import pygame

import random

from math import sin, cos, radians

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    
    # 매개변수 : 파일경로
    logo = pygame.image.load('pythonlogo.jpg')
    
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((255,255,255))

        # 
        SURFACE.blit(logo, (250,50), Rect(50,50,100,100))
       
        
        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 여러개의 그림 그리기
import pygame

import sys
import pygame

import random

from math import sin, cos, radians

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    
    # 매개변수 : 파일경로
    logo = pygame.image.load(r'strip.png')
    
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        SURFACE.fill((255,255,255))

        # 
        SURFACE.blit(logo, (250,50), Rect(50,50,100,100))
       
        
        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 여러개의 그림 그리기
import pygame

import sys
import pygame

import random

from math import sin, cos, radians

from pygame.locals import QUIT, Rect, KEYDOWN, K_LEFT, K_RIGHT

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    
    # 매개변수 : 파일경로
    strip = pygame.image.load('strip.png')
    images = []
    
    for index in range(9):
        image = pygame.Surface((24,24))
        image.blit(strip,(0,0), Rect(index * 24, 0, 24,24))
        images.append(image)
    
    counter = 0
    pos_x = 100
    
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == KEYDOWN:
                if event.key == K_LEFT:
                    pos_x -= 5
                elif event.key == K_RIGHT:
                    pos_x += 5

                    
        SURFACE.fill((0,0,0))

        SURFACE.blit(images[counter % 2 + 0], (50,50))
        SURFACE.blit(images[counter % 2 + 2], (100,50))
        SURFACE.blit(images[counter % 2 + 4], (150,50))
        SURFACE.blit(images[counter % 2 + 6], (200,50))
        counter += 1
        
        SURFACE.blit(images[8], (pos_x, 150))
        
        #SURFACE.blit(logo, (250,50), Rect(50,50,100,100))
       
        
        pygame.display.update()
        FPSCLOCK.tick(3)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 이미지 회전 1
import pygame
import sys

from pygame.locals import QUIT

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    
    # 매개변수 : 파일경로
    logo = pygame.image.load('pygamelogo.jpg')
    theta = 0
    
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        theta += 1
        SURFACE.fill((255,255,255))

        # 로고를 회전하고, 왼쪽 위가 (100,30)인 위치에 로고를 그린다.
        new_logo = pygame.transform.rotate(logo, theta)
        rect = new_logo.get_rect()
        rect.center = (200,150)
        SURFACE.blit(new_logo,rect)
       
        
        pygame.display.update()
        FPSCLOCK.tick(30)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 이미지 회전 2
import pygame

import sys
import pygame

import random

from math import sin, cos, radians

from pygame.locals import QUIT, Rect

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    
    # 매개변수 : 파일경로
    logo = pygame.image.load('pygamelogo.jpg')
    theta = 0
    
    # main routine
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()

        theta += 1
        SURFACE.fill((255,255,255))

        new_logo = pygame.transform.rotate(logo, theta)
        rect = new_logo.get_rect()
        rect.center = (200,150)
        SURFACE.blit(new_logo,rect)
       
        
        pygame.display.update()
        FPSCLOCK.tick(30)

# main 함수
if __name__ == '__main__':
    main()

# %%
# 문자 1
import sys
import pygame
from pygame.locals import QUIT

pygame.init()
SURFACE = pygame.display.set_mode((400,200))
FPSCLOCK = pygame.time.Clock()

def main():
    sysfont = pygame.font.SysFont(None, 72)
    message = sysfont.render('hello Python', True, (0,128,128))
    message_rect = message.get_rect()
    message_rect.center = (200,100)
    
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
                
        SURFACE.fill((255,255,255))
        SURFACE.blit(message, message_rect)
        pygame.display.update()
        FPSCLOCK.tick(3)
        
if __name__ == '__main__':
    main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\GJ\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# 문자 1
import sys
import pygame
from pygame.locals import QUIT

pygame.init()
SURFACE = pygame.display.set_mode((400,200))
FPSCLOCK = pygame.time.Clock()

def main():
    sysfont = pygame.font.SysFont(None, 72)
    message = sysfont.render('hello Python', True, (0,128,128))
    message_rect = message.get_rect()
    
    message_rect.center = (200,100)
    
    # 추가
    theta = 0
    scale = 1
    
    
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
                
        SURFACE.fill((255,255,255))
        
        theta += 5
        scale = (theta % 360) / 180
        
        temp_msg = pygame.transform.rotozoom(message, theta, scale)
        temp_rect = temp_msg.get_rect()
        temp_rect.center = (200,150)
        
        
        SURFACE.blit(temp_msg, temp_rect)
        pygame.display.update()
        FPSCLOCK.tick(10)
        
if __name__ == '__main__':
    main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\GJ\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# 마우스 - 이벤트 1
import sys
import pygame
from pygame.locals import QUIT, MOUSEBUTTONDOWN

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    mousepos = []
    
    while True:
        SURFACE.fill((255,255,255))
        
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == MOUSEBUTTONDOWN:
                mousepos.append(event.pos)
                
        for pos in mousepos:
            pygame.draw.circle(SURFACE, (0,255,0), pos, 5)
            
        pygame.display.update()
        FPSCLOCK.tick(10)
        
if __name__ == '__main__':
    main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# 마우스 이벤트 2
import sys
import pygame
from pygame.locals import QUIT,MOUSEBUTTONDOWN,MOUSEMOTION, MOUSEBUTTONUP

pygame.init()
SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    mousepos = []
    mousedown = False
    
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == MOUSEBUTTONDOWN:
                mousedown = True
            elif event.type == MOUSEMOTION:
                if mousedown:
                    mousepos.append(event.pos)
            elif event.type == MOUSEBUTTONUP:
                mousedown = False
                #mousepos.clear()
                
        SURFACE.fill((255,255,255))
        if len(mousepos) > 1:
            pygame.draw.lines(SURFACE, (255,0,0),False, mousepos)
            
        pygame.display.update()
        FPSCLOCK.tick(10)
        
if __name__ == '__main__':
    main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# 키 입력 - 이벤트
import sys
import pygame
from pygame.locals import QAUIT, KEYDOWN, K_LEFT, K_RIGHT, K_UP, K_DOWN

pygame.init()
pygame.key.set_repeat(5,5)

SURFACE = pygame.display.set_mode((400,300))
FPSCLOCK = pygame.time.Clock()

def main():
    # main routine
    logo = pygame.image.load('pythonlogo.jpg')
    pos = [200,150]
    
    while True:
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                sys.exit()
            elif event.type == KEYDOWN:
                if event.key == K_LEFT:
                    pos[0] -= 5
                elif event.key == K_RIGHT:
                    pos[0] += 5
                elif event.key == K_UP:
                    pos[1] -= 5
                elif event.key == K_DOWN:
                    pos[1] += 5
                    
        pos[0] = pos[0] % 400
        pos[1] = pos[1] % 300
        
        SURFACE.fill((255,255,255))
        
        rect = logo.get_rect()
        rect.center = pos
        SURFACE.blit(logo, rect)
        
        pygame.display.update()
        FPSCLOCK.tick(30)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       2 import sys
#       3 import pygame
# ----> 4 from pygame.locals import QAUIT, KEYDOWN, K_LEFT, K_RIGHT, K_UP, K_DOWN
#       6 pygame.init()
#       7 pygame.key.set_repeat(5,5)
#
# ImportError: cannot import name 'QAUIT' from 'pygame.locals' (c:\Users\GJ\AppData\Local\Programs\Python\Python39\lib\site-packages\pygame\locals.py)
